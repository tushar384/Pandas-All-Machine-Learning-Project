# %%
import pandas as pd

# %%
weather_df = pd.read_csv('weather.csv')

# %%
rides_df = pd.read_csv('cab_rides.csv')

# %%
weather_df
# Out:
#        temp                 location  clouds  pressure    rain  time_stamp  \
# 0     42.42                 Back Bay    1.00   1012.14  0.1228  1545003901
# 1     42.43              Beacon Hill    1.00   1012.15  0.1846  1545003901
# 2     42.50        Boston University    1.00   1012.15  0.1089  1545003901
# 3     42.11                   Fenway    1.00   1012.13  0.0969  1545003901
# 4     43.13       Financial District    1.00   1012.14  0.1786  1545003901
# ...     ...                      ...     ...       ...     ...         ...
# 6271  44.72            North Station    0.89   1000.69     NaN  1543819974
# 6272  44.85  Northeastern University    0.88   1000.71     NaN  1543819974
# 6273  44.82            South Station    0.89   1000.70     NaN  1543819974
# 6274  44.78         Theatre District    0.89   1000.70     NaN  1543819974
# 6275  44.69                 West End    0.89   1000.70     NaN  1543819974
#
#       humidity   wind
# 0         0.77  11.25
# ...

# %%
rides_df
# Out:
#         distance cab_type    time_stamp    destination            Source  \
# 0           0.44     Lyft  1.544950e+12  North Station  Haymarket Square
# 1           0.44     Lyft  1.543280e+12  North Station  Haymarket Square
# 2           0.44     Lyft  1.543370e+12  North Station  Haymarket Square
# 3           0.44     Lyft  1.543550e+12  North Station  Haymarket Square
# 4           0.44     Lyft  1.543460e+12  North Station  Haymarket Square
# ...          ...      ...           ...            ...               ...
# 693066      1.00     Uber  1.543710e+12      North End          West End
# 693067      1.00     Uber  1.543710e+12      North End          West End
# 693068      1.00     Uber  1.543710e+12      North End          West End
# 693069      1.00     Uber  1.543710e+12      North End          West End
# 693070      1.00     Uber  1.543710e+12      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        894 non-null    float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
weather_df.isna().sum()
# Out:
# temp             0
# location         0
# clouds           0
# pressure         0
# rain          5382
# time_stamp       0
# humidity         0
# wind             0
# dtype: int64

# %%
weather_df = weather_df.fillna(0)

# %%
weather_df.isna().sum()
# Out:
# temp          0
# location      0
# clouds        0
# pressure      0
# rain          0
# time_stamp    0
# humidity      0
# wind          0
# dtype: int64

# %%
weather_df.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind
# 0  11.25
# 1  11.32
# 2  11.07
# 3  11.09
# 4  11.49

# %%
avg_weather_df = weather_df.groupby('location').mean()

# %%
avg_weather_df
# Out:
#                               temp    clouds     pressure      rain  \
# location
# Back Bay                 39.082122  0.678432  1008.447820  0.007925
# Beacon Hill              39.047285  0.677801  1008.448356  0.008297
# Boston University        39.047744  0.679235  1008.459254  0.007738
# Fenway                   38.964379  0.679866  1008.453289  0.007343
# Financial District       39.410822  0.676730  1008.435793  0.008563
# Haymarket Square         39.067897  0.676711  1008.445239  0.008660
# North End                39.090841  0.676730  1008.441912  0.008644
# North Station            39.035315  0.676998  1008.442811  0.008649
# Northeastern University  38.975086  0.678317  1008.444168  0.007358
# South Station            39.394092  0.677495  1008.438031  0.008310
# Theatre District         38.986711  0.677763  1008.444742  0.008405
# West End                 38.983403  0.677247  1008.441090  0.008657
#
#                            time_stamp  humidity      wind
# location
# ...

# %%
avg_weather_df.isna().sum()
# Out:
# temp          0
# clouds        0
# pressure      0
# rain          0
# time_stamp    0
# humidity      0
# wind          0
# dtype: int64

# %%
avg_weather_df = avg_weather_df.drop(['time_stamp'],axis = 'columns')

# %%
avg_weather_df.head()
# Out:
#                          temp    clouds     pressure      rain  humidity  \
# location
# Back Bay            39.082122  0.678432  1008.447820  0.007925  0.764073
# Beacon Hill         39.047285  0.677801  1008.448356  0.008297  0.765048
# Boston University   39.047744  0.679235  1008.459254  0.007738  0.763786
# Fenway              38.964379  0.679866  1008.453289  0.007343  0.767266
# Financial District  39.410822  0.676730  1008.435793  0.008563  0.754837
#
#                         wind
# location
# Back Bay            6.778528
# Beacon Hill         6.810325
# Boston University   6.692180
# Fenway              6.711721
# Financial District  6.860019

# %%
rides_df
# Out:
#         distance cab_type    time_stamp    destination            Source  \
# 0           0.44     Lyft  1.544950e+12  North Station  Haymarket Square
# 1           0.44     Lyft  1.543280e+12  North Station  Haymarket Square
# 2           0.44     Lyft  1.543370e+12  North Station  Haymarket Square
# 3           0.44     Lyft  1.543550e+12  North Station  Haymarket Square
# 4           0.44     Lyft  1.543460e+12  North Station  Haymarket Square
# ...          ...      ...           ...            ...               ...
# 693066      1.00     Uber  1.543710e+12      North End          West End
# 693067      1.00     Uber  1.543710e+12      North End          West End
# 693068      1.00     Uber  1.543710e+12      North End          West End
# 693069      1.00     Uber  1.543710e+12      North End          West End
# 693070      1.00     Uber  1.543710e+12      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
rides_df.isna().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# Source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# dtype: int64

# %%
rides_df = rides_df.dropna(axis = 0)

# %%
rides_df
# Out:
#         distance cab_type    time_stamp    destination            Source  \
# 0           0.44     Lyft  1.544950e+12  North Station  Haymarket Square
# 1           0.44     Lyft  1.543280e+12  North Station  Haymarket Square
# 2           0.44     Lyft  1.543370e+12  North Station  Haymarket Square
# 3           0.44     Lyft  1.543550e+12  North Station  Haymarket Square
# 4           0.44     Lyft  1.543460e+12  North Station  Haymarket Square
# ...          ...      ...           ...            ...               ...
# 693065      1.00     Uber  1.543710e+12      North End          West End
# 693066      1.00     Uber  1.543710e+12      North End          West End
# 693067      1.00     Uber  1.543710e+12      North End          West End
# 693069      1.00     Uber  1.543710e+12      North End          West End
# 693070      1.00     Uber  1.543710e+12      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
rides_df.isna().sum()
# Out:
# distance            0
# cab_type            0
# time_stamp          0
# destination         0
# Source              0
# price               0
# surge_multiplier    0
# id                  0
# product_id          0
# name                0
# dtype: int64

# %%
rides_df['price']
# Out:
# 0          5.0
# 1         11.0
# 2          7.0
# 3         26.0
# 4          9.0
#           ...
# 693065     9.5
# 693066    13.0
# 693067     9.5
# 693069    27.0
# 693070    10.0
# Name: price, Length: 637976, dtype: float64

# %%
avg_weather_df.head()
# Out:
#                          temp    clouds     pressure      rain  humidity  \
# location
# Back Bay            39.082122  0.678432  1008.447820  0.007925  0.764073
# Beacon Hill         39.047285  0.677801  1008.448356  0.008297  0.765048
# Boston University   39.047744  0.679235  1008.459254  0.007738  0.763786
# Fenway              38.964379  0.679866  1008.453289  0.007343  0.767266
# Financial District  39.410822  0.676730  1008.435793  0.008563  0.754837
#
#                         wind
# location
# Back Bay            6.778528
# Beacon Hill         6.810325
# Boston University   6.692180
# Fenway              6.711721
# Financial District  6.860019

# %%
rides_df.head()
# Out:
#    distance cab_type    time_stamp    destination            Source  price  \
# 0      0.44     Lyft  1.544950e+12  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1.543280e+12  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1.543370e+12  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1.543550e+12  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1.543460e+12  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# ...

# %%
# there rides_df 'source' column  i filled avg_wether_df data

# %%
source_weather_df = avg_weather_df.rename(
    columns={
        'location': 'Source',
        'temp': 'Source_temp',
        'clouds': 'Source_clouds',
        'pressure': 'Source_pressure',
        'rain': 'Source_rain',
        'humidity': 'Source_humidity',
        'wind': 'Source_wind'
    }
)

source_weather_df
# Out:
#                          Source_temp  Source_clouds  Source_pressure  \
# location
# Back Bay                   39.082122       0.678432      1008.447820
# Beacon Hill                39.047285       0.677801      1008.448356
# Boston University          39.047744       0.679235      1008.459254
# Fenway                     38.964379       0.679866      1008.453289
# Financial District         39.410822       0.676730      1008.435793
# Haymarket Square           39.067897       0.676711      1008.445239
# North End                  39.090841       0.676730      1008.441912
# North Station              39.035315       0.676998      1008.442811
# Northeastern University    38.975086       0.678317      1008.444168
# South Station              39.394092       0.677495      1008.438031
# Theatre District           38.986711       0.677763      1008.444742
# West End                   38.983403       0.677247      1008.441090
#
# ...

# %%
# same procedure for column destination

# %%
destination_weather_df = avg_weather_df.rename(
    columns={
        'location': 'destination',
        'temp': 'destination_temp',
        'clouds': 'destination_clouds',
        'pressure': 'destination_pressure',
        'rain': 'destination_rain',
        'humidity': 'destination_humidity',
        'wind': 'destination_wind'
    }
)

destination_weather_df
# Out:
#                          destination_temp  destination_clouds  \
# location
# Back Bay                        39.082122            0.678432
# Beacon Hill                     39.047285            0.677801
# Boston University               39.047744            0.679235
# Fenway                          38.964379            0.679866
# Financial District              39.410822            0.676730
# Haymarket Square                39.067897            0.676711
# North End                       39.090841            0.676730
# North Station                   39.035315            0.676998
# Northeastern University         38.975086            0.678317
# South Station                   39.394092            0.677495
# Theatre District                38.986711            0.677763
# West End                        38.983403            0.677247
#
#                          destination_pressure  destination_rain  \
# location
# Back Bay                          1008.447820          0.007925
# ...

# %%
# merge data in rides_df

# %%
def preprocessing_inputs(df):
    df = df.copy()
    return df

# %%
X = preprocessing_inputs(rides_df)

# %%
X

# %%
{column: len(X[column].unique()) for column in X.columns}

# %%
{column: len(X[column].unique()) for column in X.select_dtypes('object')}
