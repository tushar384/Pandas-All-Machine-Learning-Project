# %%
import pandas as pd

# %%
df = pd.read_csv('Absent_work.csv')

# %%
df
# Out:
#     ID;Reason for absence;Month of absence;Day of the week;Seasons;Transportation expense;Distance from Residence to Work;Service time;Age;Work load Average/day ;Hit target;Disciplinary failure;Education;Son;Social drinker;Social smoker;Pet;Weight;Height;Body mass index;Absenteeism time in hours
# 0    11;26;7;3;1;289;36;13;33;239.554;97;0;1;2;1;0;...
# 1    36;0;7;3;1;118;13;18;50;239.554;97;1;1;1;1;0;0...
# 2    3;23;7;4;1;179;51;18;38;239.554;97;0;1;0;1;0;0...
# 3    7;7;7;5;1;279;5;14;39;239.554;97;0;1;2;1;1;0;6...
# 4    11;23;7;5;1;289;36;13;33;239.554;97;0;1;2;1;0;...
# ..                                                 ...
# 735  11;14;7;3;1;289;36;13;33;264.604;93;0;1;2;1;0;...
# 736  1;11;7;3;1;235;11;14;37;264.604;93;0;3;1;0;0;1...
# 737  4;0;0;3;1;118;14;13;40;271.219;95;0;1;1;1;0;8;...
# 738  8;0;0;4;2;231;35;14;39;271.219;95;0;1;2;1;0;2;...
# 739  35;0;0;6;3;179;45;14;53;271.219;95;0;1;1;0;0;1...
#
# [740 rows x 1 columns]

# %%
df = pd.read_csv('Absent_work.csv',delimiter = ';')

# %%
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
df.isna().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df.isna().describe()
# Out:
#            ID Reason for absence Month of absence Day of the week Seasons  \
# count     740                740              740             740     740
# unique      1                  1                1               1       1
# top     False              False            False           False   False
# freq      740                740              740             740     740
#
#        Transportation expense Distance from Residence to Work Service time  \
# count                     740                             740          740
# unique                      1                               1            1
# top                     False                           False        False
# freq                      740                             740          740
#
#           Age Work load Average/day   ... Disciplinary failure Education  \
# count     740                    740  ...                  740       740
# ...

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df = df.drop(['ID'],axis = 1)

# %%
df.head()
# Out:
#    Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                  26                 7                3        1
# 1                   0                 7                3        1
# 2                  23                 7                4        1
# 3                   7                 7                5        1
# 4                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   Hit target  Disciplinary failure  Education  Son  \
# ...

# %%
df.head()
# Out:
#    Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                  26                 7                3        1
# 1                   0                 7                3        1
# 2                  23                 7                4        1
# 3                   7                 7                5        1
# 4                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   Hit target  Disciplinary failure  Education  Son  \
# ...

# %%
x = df.drop(['Absenteeism time in hours'],axis = 'columns')

# %%
y = df['Absenteeism time in hours']

# %%
x
# Out:
#      Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                    26                 7                3        1
# 1                     0                 7                3        1
# 2                    23                 7                4        1
# 3                     7                 7                5        1
# 4                    23                 7                5        1
# ..                  ...               ...              ...      ...
# 735                  14                 7                3        1
# 736                  11                 7                3        1
# 737                   0                 0                3        1
# 738                   0                 0                4        2
# 739                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
y
# Out:
# 0      4
# 1      0
# 2      2
# 3      4
# 4      2
#       ..
# 735    8
# 736    4
# 737    0
# 738    0
# 739    0
# Name: Absenteeism time in hours, Length: 740, dtype: int64

# %%
df.isna().sum()
# Out:
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
cols_to_fillna = (['Month of absence','Day of the week','Seasons', 'Transportation expense','Distance from Residence to Work','Service time',
                   'Age','Hit target','Disciplinary failure','Education','Son',
                   'Social drinker','Social smoker','Pet', 'Weight', 'Height', 'Body mass index', 'Absenteeism time in hours'])

# %%
df[cols_to_fillna] = df[cols_to_fillna].fillna(0)

# %%
df.isna().sum()
# Out:
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
x1 = df.drop(['Absenteeism time in hours'],axis = 'columns')

# %%
y1 = df['Absenteeism time in hours']

# %%
x1
# Out:
#      Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                    26                 7                3        1
# 1                     0                 7                3        1
# 2                    23                 7                4        1
# 3                     7                 7                5        1
# 4                    23                 7                5        1
# ..                  ...               ...              ...      ...
# 735                  14                 7                3        1
# 736                  11                 7                3        1
# 737                   0                 0                3        1
# 738                   0                 0                4        2
# 739                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
y1
# Out:
# 0      4
# 1      0
# 2      2
# 3      4
# 4      2
#       ..
# 735    8
# 736    4
# 737    0
# 738    0
# 739    0
# Name: Absenteeism time in hours, Length: 740, dtype: int64

# %%
 from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x1,y1,test_size = 0.2)

# %%
from sklearn.linear_model import  LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.14849379669487595

# %%
from sklearn.svm import SVC
svm = SVC(gamma = 'auto' ,C = 40 , kernel = 'rbf')

# %%
svm.fit(X_train,Y_train)
# Out:
# SVC(C=40, gamma='auto')

# %%
svm.score(X_test,Y_test)
# Out:
# 0.3918918918918919

# %%
svm = SVC(gamma = 'auto' ,C = 10 , kernel = 'linear')

# %%
svm.fit(X_train,Y_train)
# Out:
# SVC(C=10, gamma='auto', kernel='linear')

# %%
svm.score(X_test,Y_test)
# Out:
# 0.4391891891891892

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 60)

# %%
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=60)

# %%
rfc.score(X_test,Y_test)
# Out:
# 0.527027027027027

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.score(X_test,Y_test)
# Out:
# 0.41216216216216217

# %%
from sklearn.naive_bayes import GaussianNB
gn = GaussianNB()

# %%
gn.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
gn.score(X_test,Y_test)
# Out:
# 0.16891891891891891

# %%
rfc.predict(X_test)
# Out:
# array([ 2,  8,  8,  3,  8,  2,  8,  2,  2,  8,  4,  2,  8,  8,  8,  1,  8,
#         8,  0,  2,  3,  0,  8,  8,  0,  2,  4,  0,  8,  2,  2,  2,  3,  3,
#         2,  3,  3,  3,  8,  4,  8,  8,  3,  2,  8,  0,  2,  3,  4,  2,  2,
#         8,  4,  8,  1,  2,  2,  3,  1,  1,  0,  2,  8,  8,  8,  2,  1,  2,
#         3,  3,  8,  8,  8,  8,  1,  4,  8,  1,  8,  8,  2,  8,  8,  0,  2,
#         8,  3,  8,  2,  4,  2, 64,  2,  4,  1,  4,  4,  2,  8,  2,  0,  3,
#         3,  8,  8,  8,  3,  8,  7,  8,  1,  8,  4, 16,  3,  8,  3,  1,  2,
#         2,  8,  0,  1,  4, 24,  4,  0,  3,  8,  2,  1,  2,  2,  8,  8,  8,
#         3,  8,  8,  1,  2,  8,  8,  2,  4,  8,  8,  1], dtype=int64)

# %%
y_predict = rfc.predict(X_test)
y_predict
# Out:
# array([ 2,  8,  8,  3,  8,  2,  8,  2,  2,  8,  4,  2,  8,  8,  8,  1,  8,
#         8,  0,  2,  3,  0,  8,  8,  0,  2,  4,  0,  8,  2,  2,  2,  3,  3,
#         2,  3,  3,  3,  8,  4,  8,  8,  3,  2,  8,  0,  2,  3,  4,  2,  2,
#         8,  4,  8,  1,  2,  2,  3,  1,  1,  0,  2,  8,  8,  8,  2,  1,  2,
#         3,  3,  8,  8,  8,  8,  1,  4,  8,  1,  8,  8,  2,  8,  8,  0,  2,
#         8,  3,  8,  2,  4,  2, 64,  2,  4,  1,  4,  4,  2,  8,  2,  0,  3,
#         3,  8,  8,  8,  3,  8,  7,  8,  1,  8,  4, 16,  3,  8,  3,  1,  2,
#         2,  8,  0,  1,  4, 24,  4,  0,  3,  8,  2,  1,  2,  2,  8,  8,  8,
#         3,  8,  8,  1,  2,  8,  8,  2,  4,  8,  8,  1], dtype=int64)

# %%
from sklearn.metrics import r2_score

# %%
t = r2_score(Y_test,y_predict)

# %%
t
# Out:
# -0.05792891914814513

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Y_test,y_predict)

# %%
plt.scatter(Y_test,y_predict)
