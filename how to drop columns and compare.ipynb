# %%
import pandas as pd

# %%
dict1 = {
    "name" :["swapnil","krish","lucky","sheha"],
    "markes":[45,67,89,34],
    "city":["mumbai","pune","vasai","mira road"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       name  markes       city
# 0  swapnil      45     mumbai
# 1    krish      67       pune
# 2    lucky      89      vasai
# 3    sheha      34  mira road

# %%
df.to_csv("friends.csv")

# %%
df.pd.read_csv("forecast_data.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1afe43ea34a9> in <module>
# ----> 1 df.pd.read_csv("forecast_data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
df = pd.read_csv("forecast_data.csv")

# %%
df
df
# Out:
#                Name            Date time  Maximum Temperature  \
# 0   Pune, MH, India  11/20/2020 18:30:00                 74.7
# 1   Pune, MH, India  11/21/2020 06:30:00                 86.1
# 2   Pune, MH, India  11/21/2020 18:30:00                 75.8
# 3   Pune, MH, India  11/22/2020 06:30:00                 84.1
# 4   Pune, MH, India  11/22/2020 18:30:00                 75.1
# 5   Pune, MH, India  11/23/2020 06:30:00                 83.7
# 6   Pune, MH, India  11/23/2020 18:30:00                 74.6
# 7   Pune, MH, India  11/24/2020 06:30:00                 81.2
# 8   Pune, MH, India  11/24/2020 18:30:00                 75.1
# 9   Pune, MH, India  11/25/2020 06:30:00                 80.5
# 10  Pune, MH, India  11/25/2020 18:30:00                 74.5
# 11  Pune, MH, India  11/26/2020 06:30:00                 80.5
# 12  Pune, MH, India  11/26/2020 18:30:00                 71.9
# 13  Pune, MH, India  11/27/2020 06:30:00                 78.3
# ...

# %%
t=df.Temperature.max()
# Out:
# 80.3

# %%
df.Temperature==df.Temperature.max()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Temperature, dtype: bool

# %%
df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-b1a68fcb0857> in <module>
# ----> 1 df.type()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df = pd.read_csv("canada_per_capita_income.csv")

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df=year()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b6a3d2d8d944> in <module>
# ----> 1 df=year()
#
# NameError: name 'year' is not defined

# %%
df.index=false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5358465433b0> in <module>
# ----> 1 df.index=false
#
# NameError: name 'false' is not defined

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.head().year
# Out:
# 0    1970
# 1    1971
# 2    1972
# 3    1973
# 4    1974
# Name: year, dtype: int64

# %%
df.tail()
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %%
df.tail().per capita income
# Out:
#   File "<ipython-input-47-251bcd9b6625>", line 1
#     df.tail().per capita income
#                   ^
# SyntaxError: invalid syntax

# %%
df.tail()
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %%
df.per capita income
# Out:
#   File "<ipython-input-49-be144c0e8e24>", line 1
#     df.per capita income
#            ^
# SyntaxError: invalid syntax

# %%
df.head().year
# Out:
# 0    1970
# 1    1971
# 2    1972
# 3    1973
# 4    1974
# Name: year, dtype: int64

# %%
df.row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-a0fe53b7fddd> in <module>
# ----> 1 df.row
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
df= pd.read_csv("canada_per_capita_income.csv",nrows=5)

# %%
df
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df = pd.read_excel("stock_data.xlsx",header=none,nrows=7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-2939d02f7da0> in <module>
# ----> 1 df = pd.read_excel("stock_data.xlsx",header=none)
#
# NameError: name 'none' is not defined

# %%
df
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.head()
# Out:
#    Sr.                             Stock Name      Symbol      Links   % Chg  \
# 0   58                    IDFC First Bank Ltd  IDFCFIRSTB  P&F | F.A  0.0967
# 1   59       Bharat Heavy Electricals Limited        BHEL  P&F | F.A  0.0736
# 2   53  Oil & Natural Gas Corporation Limited        ONGC  P&F | F.A  0.0677
# 3   38              Adani Enterprises Limited    ADANIENT  P&F | F.A  0.0534
# 4   57       Steel Authority Of India Limited        SAIL  P&F | F.A  0.0523
#
#     Price     Volume
# 0   36.85  127776755
# 1   31.35   94900663
# 2   76.50   44104728
# 3  409.05    7282107
# 4   43.25   70282568

# %%
df.Volume.max()
# Out:
# 127776755

# %%
df[df.Volume==df.Volume.max()]
# Out:
#    Sr.           Stock Name      Symbol      Links   % Chg  Price     Volume
# 0   58  IDFC First Bank Ltd  IDFCFIRSTB  P&F | F.A  0.0967  36.85  127776755

# %%
df
  df[df.Volume<df.Volume.max()]
# Out:
#   File "<ipython-input-91-91737e4dcef8>", line 2
#     df[df.Volume<df.Volume.max()]
#     ^
# IndentationError: unexpected indent

# %%
 ori_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-2d872adb7a2d> in <module>
# ----> 1 ori_data.head()
#
# NameError: name 'ori_data' is not defined

# %%
df = pd.read_csv("nifty5023.csv",header=none,nrows =2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-b45edcaf84e7> in <module>
# ----> 1 df = pd.read_csv("nifty5023.csv",header=none,nrows = 4)
#
# NameError: name 'none' is not defined

# %%
df
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.head()
# Out:
#     SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0    NIFTY 50  12,960.30  12,968.85  12,825.70      12,859.05  12,926.45
# 1        ONGC      72.00      77.80      71.80          71.65      76.40
# 2  INDUSINDBK     836.00     880.90     832.50         811.00     841.70
# 3        GAIL      99.00     101.50      97.60          97.45     100.90
# 4     DRREDDY   4,685.00   4,870.00   4,671.10       4,670.95   4,835.00
#
#    CHNG \n  %CHNG \n  VOLUME \n(shares)              VALUE    52W H \n  \
# 0    67.40      0.52          633115503  420,310,630,885.56  12,968.85
# 1     4.75      6.63           44111480    3,310,125,459.20     134.65
# 2    30.70      3.79           39219487   33,491,873,118.52   1,596.55
# 3     3.45      3.54           29687033    2,956,234,746.14     133.35
# 4   164.05      3.51            2152603   10,342,396,373.80   5,512.65
#
#    52W L \n  365 D % CHNG \n 21-Nov-2019  30 D % CHNG \n 21-Oct-2020
# ...

# %%
df = pd.read_csv("nifty5023.csv",nrows=4)

# %%
df
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  12,960.30  12,968.85  12,825.70      12,859.05  12,926.45
# 1         ONGC      72.00      77.80      71.80          71.65      76.40
# 2   INDUSINDBK     836.00     880.90     832.50         811.00     841.70
# 3         GAIL      99.00     101.50      97.60          97.45     100.90
# 4      DRREDDY   4,685.00   4,870.00   4,671.10       4,670.95   4,835.00
# 5         INFY   1,105.00   1,144.80   1,101.95       1,103.35   1,138.50
# 6        TECHM     838.00     869.40     836.75         837.55     863.45
# 7        WIPRO     348.00     357.40     346.00         346.30     356.60
# 8     RELIANCE   1,951.00   1,970.00   1,926.25       1,899.50   1,955.20
# 9         BPCL     386.00     395.55     383.00         383.30     393.20
# 10         TCS   2,690.00   2,730.00   2,665.00       2,660.25   2,727.25
# 11     HCLTECH     825.00     842.00     816.25         819.25     838.50
# ...

# %%
df.head()
# Out:
#     SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0    NIFTY 50  12,960.30  12,968.85  12,825.70      12,859.05  12,926.45
# 1        ONGC      72.00      77.80      71.80          71.65      76.40
# 2  INDUSINDBK     836.00     880.90     832.50         811.00     841.70
# 3        GAIL      99.00     101.50      97.60          97.45     100.90
# 4     DRREDDY   4,685.00   4,870.00   4,671.10       4,670.95   4,835.00
#
#    CHNG \n  %CHNG \n  VOLUME \n(shares)              VALUE    52W H \n  \
# 0    67.40      0.52          633115503  420,310,630,885.56  12,968.85
# 1     4.75      6.63           44111480    3,310,125,459.20     134.65
# 2    30.70      3.79           39219487   33,491,873,118.52   1,596.55
# 3     3.45      3.54           29687033    2,956,234,746.14     133.35
# 4   164.05      3.51            2152603   10,342,396,373.80   5,512.65
#
#    52W L \n  365 D % CHNG \n 21-Nov-2019  30 D % CHNG \n 21-Oct-2020
# ...

# %%
df =
# Out:
#   File "<ipython-input-124-dbf021391ec5>", line 1
#     df = LTP\n
#               ^
# SyntaxError: unexpected character after line continuation character

# %%
df = pd.read_csv("nifty5023.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-126-a8220396e283> in <module>
# ----> 1 df = pd.read_csv("nifty5023.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
df = pd.read_csv("nifty5023.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-127-a8220396e283> in <module>
# ----> 1 df = pd.read_csv("nifty5023.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...
